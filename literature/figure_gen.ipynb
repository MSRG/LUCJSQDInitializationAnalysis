# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def potential(x):
    return 1/x**2 - 1/x

# %%
SIZE = 18

plt.rc('font', size=SIZE) # controls default text sizes
plt.rc('axes', titlesize=SIZE) # fontsize of the axes title
plt.rc('axes', labelsize=SIZE) # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE) # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE) # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE-2) # legend fontsize
plt.rc('figure', titlesize=SIZE) # fontsize of the figure title

# %%
r = np.linspace(1,7,1000)
fig, ax = plt.subplots()
# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.plot(r, potential(r)+1, color='green', linewidth='5')
plt.ylabel('Potential Energy [mH]', fontsize=20)
plt.xlabel(r'Radius [$\AA$]', fontsize=20)
plt.savefig('potential_curve.svg')
plt.show()

# %% [markdown]
# # $ h_{pq}$ & $h_{pqrs}$

# %%
SIZE = 18

plt.rc('font', size=SIZE) # controls default text sizes
plt.rc('axes', titlesize=SIZE) # fontsize of the axes title
plt.rc('axes', labelsize=SIZE) # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE) # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE) # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE-2) # legend fontsize
plt.rc('figure', titlesize=SIZE) # fontsize of the figure title

# %%
fig, ax = plt.subplots()
# Remove the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
r = np.linspace(1,6,1000)
plt.plot(r, r*np.log(r), color='blue', linewidth='3', label="DDCC RF")
plt.plot(r, r**6, color='red', linewidth='3', label="CCSD")
plt.legend()
plt.ylabel('Algorithmic Complexity')
plt.xlabel('System Size')
plt.savefig('complexity_madness.png')
plt.show()

# %% [markdown]
# # $H \ket{\psi_0} = E \ket{\psi_0} $

# %% [markdown]
# # $t_{ij}^{ab}$
