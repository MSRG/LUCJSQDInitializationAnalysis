# %%
import os
import sys
import time
import psutil
from glob import glob
from functools import partial
from shutil import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

import pyscf
from pyscf import gto, scf, mcscf, cc
import ffsim

from qiskit import QuantumCircuit, QuantumRegister
from qiskit.primitives import StatevectorSampler, BitArray
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

from qiskit_addon_sqd.fermion import SCIResult, diagonalize_fermionic_hamiltonian
from qiskit_addon_sqd.counts import bit_array_to_arrays

from ansatzmap import get_zigzag_physical_layout
from DDLUCJ import DDLUCJ, GrabAmps



# 1. Try SLURM_NTASKS (multi-node / MPI tasks) or SLURM_CPUS_PER_TASK (multithreading)
slurm_tasks = os.environ.get("SLURM_NTASKS")
slurm_cpus_per_task = os.environ.get("SLURM_CPUS_PER_TASK")

if slurm_tasks or slurm_cpus_per_task:
    # Use SLURM allocation
    n_jobs = int(slurm_tasks or 1) * int(slurm_cpus_per_task or 1)
    env_type = "SLURM Cluster"
else:
    # Fallback for local Debian desktop (logical cores/threads)
    n_jobs = os.cpu_count()  # Or use psutil.cpu_count(logical=False) for physical cores only
    env_type = "Local Desktop"

print(f"[{env_type}] Configured n_jobs / threads: {n_jobs}")
# Out:
# [Local Desktop] Configured n_jobs / threads: 12

# %%
# # Create directories to store energies and output files
# os.makedirs('./energies', exist_ok=True)
# os.makedirs('./jobids', exist_ok=True)

# Load metadata
moldf = pd.read_csv('molecules.csv')
activespacedf = pd.read_csv("active_spaces.csv")
energyDF = pd.read_csv("../../../classical/energies.csv", index_col=0)

BasisSets = ['STO-3G', 'cc-pVDZ', 'aug-cc-pVDZ']

# %%
cat ./energies/ammonia_LUCJ_L1_cc-pVDZ_ML_exact_StateVector_Shots10000.txt
# Out:
# Basis Set: cc-pVDZ
# Molecule: ammonia
# Method: LUCJ(L=1)/ML_exact
# Energy: -56.1971442461354
# Subspace Dimension: 4

# %%
pd.concat([pd.read_csv(i,delimiter=':',index_col=0,header=None).T for i in glob("./energies/*StateVector_Shots*txt")])
# Out:
# 0      Basis Set  Molecule               Method                Energy  \
# 1        cc-pVDZ   ammonia   LUCJ(L=1)/ML_exact     -56.1971442461354
# 1         STO-3G   methane     LUCJ(L=1)/zeroes   -39.726622999777305
# 1    aug-cc-pVDZ   ammonia        LUCJ(L=1)/MP2    -56.20522953838111
# 1         STO-3G   methane        LUCJ(L=3)/MP2    -39.73709354591391
# 1         STO-3G   methane     LUCJ(L=1)/random    -39.80605267033356
# ..           ...       ...                  ...                   ...
# 1         STO-3G   methane         LUCJ(L=5)/ML   -39.743827062734596
# 1        cc-pVDZ   ammonia        LUCJ(L=5)/MP2    -56.19576188035034
# 1         STO-3G   methane         LUCJ(L=2)/ML   -39.738190087234074
# 1    aug-cc-pVDZ   ammonia   LUCJ(L=4)/ML_exact    -56.20522770136592
# 1    aug-cc-pVDZ   methane        LUCJ(L=3)/MP2   -40.199614063351234
#
# 0  Subspace Dimension
# 1                   4
# 1                   1
# 1                   4
# 1                 121
# 1               15625
# ..                ...
# 1                 144
# 1                   4
# 1                 100
# 1                   4
# 1                   1
#
# [180 rows x 5 columns]

# %%
results_data = []
# for shots in np.logspace(4,7,3).astype(int):
for shots in [10000]:
    for row in tqdm(moldf.sort_values(by=['num_orbitals','n_electrons']).itertuples(), total=len(moldf), desc="Molecules"):
        moldict = row._asdict()
        name = moldict['molecule']
        n_electrons = int(moldict['n_electrons'])
        num_orbitals = int(moldict['num_orbitals'])
        xyzname = moldict['mol_filename']
        pathxyz = os.path.join("../../../classical/structures/", xyzname)
        
        for basis in BasisSets:
            ampdict = GrabAmps(name, basis)
            
            for k, v in ampdict.items():
                t1, t2 = v
                for L in range(1, 6):
                    energy_file = f"./energies/{name}_LUCJ_L{L}_{basis}_{k}_StateVector_Shots{shots}.txt"
                    
                    # Skip if already computed
                    if os.path.exists(energy_file):
                        print(f"Skipping already calculated: {name}_L{L}_{basis}_{k}")
                        continue
    
                    print(f"--- Running Statevector + Fulqrum Postprocessing: {name} (L={L}, Basis={basis}, Amps={k}) ---")
                    
                    # 1. Initialize with local Statevector sampler mode
                    initDDLUCJ = DDLUCJ(
                        StructurePath=pathxyz, 
                        BasisSet=basis, 
                        NElec=n_electrons,
                        NOrb=num_orbitals,
                        injected=True,
                        t1=t1, 
                        t2=t2,
                        n_reps=L,
                        backend="statevector",
                        optimization_level=3,
                        shots=shots,
                        temp_dir="./",
                        clean_temp_dir=True,
                        n_jobs=1,  # Set n_jobs to 1 to prevent Dice C++ fallback
                        num_batches=10,
                        max_iterations=5,
                        samples_per_batch=1000,
                        verbose=True
                    )
                    
                    # 2. Execute sampling and Fulqrum postprocessing in one call
                    # Fulqrum directly returns (total_energy, subspace_dimension)
                    total_energy, subspace_dim = initDDLUCJ(
                        postprocess=True, 
                        usefulqrum=True
                    )
                    
                    # Convert scalar NumPy array/value to a standard Python float
                    energy_val = float(np.squeeze(total_energy))
                    
                    print(f"Calculated Total Energy: {energy_val:.8f} Ha | Subspace Dim: {subspace_dim}")
                    
                    # 3. Save results to text file
                    with open(energy_file, 'w') as f:
                        f.write(f"Basis Set: {basis}\n")
                        f.write(f"Molecule: {name}\n")
                        f.write(f"Method: LUCJ(L={L})/{k}\n")
                        f.write(f"Energy: {energy_val}\n")
                        f.write(f"Subspace Dimension: {subspace_dim}\n")
                    
                    results_data.append({
                        "Molecule": name,
                        "Basis Set": basis,
                        "Layers": L,
                        "Injection": k,
                        "Energy": energy_val,
                        "Subspace Dim": subspace_dim
                    })
                    
# Summary DataFrame
df_results = pd.DataFrame(results_data)
df_results.to_csv("statevector_fulqrum_energies.csv", index=False)
df_results.head()
# Out:
# Molecules:   0%|          | 0/12 [00:00<?, ?it/s]
# --- Running Statevector + Fulqrum Postprocessing: water (L=1, Basis=STO-3G, Amps=MP2) ---
# Active Space Orbitals: 7, Electrons: 10, Frozen: 0
# Active indices: [0, 1, 2, 3, 4, 5, 6]
# Transpiled circuit for local StatevectorSampler simulation.
# Executing simulation using local StatevectorSampler...
# ITERATION 0
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000408 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.003860 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0033 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000010 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002346 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000009 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002235 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002098 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002316 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000010 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002273 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002238 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002225 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002402 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002309 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
# Iter 0 took: 0.0325 seconds
#
# ITERATION 1
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002171 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002326 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002252 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002552 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002264 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002399 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002126 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002227 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002212 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002299 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
# Iter 1 took: 0.0259 seconds
#
# ITERATION 2
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002227 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002264 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002261 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002194 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000008 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002206 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000010 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002278 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002539 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0002 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000010 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002219 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002248 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002182 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
# Iter 2 took: 0.0259 seconds
#
# ITERATION 3
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002211 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002259 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002185 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002262 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002221 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002282 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002175 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002237 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002189 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002210 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
# Iter 3 took: 0.0250 seconds
#
# ITERATION 4
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002173 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002248 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002197 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002275 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002209 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002194 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002221 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002264 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002133 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
#   num total half strs:  5
#   num selected half strs:  5
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 5 x 5 = 25
#   Operator projection took: 0.002193 seconds
#   CSR matrix memory: 0.004322 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.15286901]
#   Total Energy: [-74.98434228]
#   num carryover full strs: 25
# Iter 4 took: 0.0249 seconds
#
# Calculated Total Energy: -74.98434228 Ha | Subspace Dim: 25
# --- Running Statevector + Fulqrum Postprocessing: water (L=2, Basis=STO-3G, Amps=MP2) ---
# Active Space Orbitals: 7, Electrons: 10, Frozen: 0
# Active indices: [0, 1, 2, 3, 4, 5, 6]
# Transpiled circuit for local StatevectorSampler simulation.
# Executing simulation using local StatevectorSampler...
# ITERATION 0
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000011 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002299 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0003 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002287 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002318 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002153 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002213 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002217 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002182 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002548 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002217 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002216 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
# Iter 0 took: 0.0259 seconds
#
# ITERATION 1
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002285 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002150 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002172 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002270 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002313 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002129 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002263 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002161 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002159 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002159 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
# Iter 1 took: 0.0246 seconds
#
# ITERATION 2
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002323 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002562 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002208 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002322 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002182 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002246 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002163 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002167 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002168 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000004 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002559 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
# Iter 2 took: 0.0254 seconds
#
# ITERATION 3
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000004 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002179 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000009 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002212 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002144 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000004 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002149 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002252 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002195 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002523 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002278 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002197 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002204 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
# Iter 3 took: 0.0247 seconds
#
# ITERATION 4
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000004 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002323 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002250 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000007 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002150 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000006 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002180 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002286 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002163 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002200 seconds
#   CSR matrix memory: 0.002079 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0001 seconds
#   Electronic Energy: [-84.14330426]
#   Total Energy: [-74.97477753]
#   num carryover full strs: 16
#   num total half strs:  4
#   num selected half strs:  4
#   Half strs construction took: 0.0000 seconds
#   Subspace construction took: 0.000005 seconds
#   Subspace dimension: 4 x 4 = 16
#   Operator projection took: 0.002169 seconds
#   CSR matrix memory: 0.002079 MBs
# ...
#   Subspace construction took: 0.000063 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004860 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0023 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000072 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.007935 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0001 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0023 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
# Iter 1 took: 0.0784 seconds
#
# ITERATION 2
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000067 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005475 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0011 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000062 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004971 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0011 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000063 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005397 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0023 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000061 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.006099 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0013 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000067 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005441 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0014 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000065 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004811 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0010 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000067 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005104 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0017 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000062 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005343 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0012 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000069 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005470 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0012 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000076 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005233 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0010 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
# Iter 2 took: 0.0758 seconds
#
# ITERATION 3
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000067 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005646 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0023 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000070 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005681 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0021 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000072 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005443 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0015 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000065 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005604 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0029 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000072 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005450 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0014 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000060 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004977 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0011 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000059 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.008881 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0013 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000075 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005749 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0012 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000068 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005122 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0010 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000058 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004979 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0014 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
# Iter 3 took: 0.0826 seconds
#
# ITERATION 4
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000074 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.006360 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0015 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000058 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005863 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0011 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000063 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.004987 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0010 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000061 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005056 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0011 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000061 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005781 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0012 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000069 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005004 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0014 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000068 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005815 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0014 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000065 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.007601 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0010 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000062 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.006202 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0015 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
#   num total half strs:  21
#   num selected half strs:  21
#   Half strs construction took: 0.0001 seconds
#   Subspace construction took: 0.000067 seconds
#   Subspace dimension: 21 x 21 = 441
#   Operator projection took: 0.005896 seconds
#   CSR matrix memory: 0.420780 MBs
#   Initial guess vector v0 construction took: 0.0000 seconds
#   Starting eigensolving ...
#   Eigensolving took: 0.0018 seconds
#   Electronic Energy: [-85.20950914]
#   Total Energy: [-76.04098241]
#   num carryover full strs: 29
# Iter 4 took: 0.0805 seconds
#
# Calculated Total Energy: -76.04098241 Ha | Subspace Dim: 441
# --- Running Statevector + Fulqrum Postprocessing: water (L=3, Basis=aug-cc-pVDZ, Amps=random) ---
# Active Space Orbitals: 7, Electrons: 10, Frozen: 0
# Active indices: [0, 1, 2, 3, 4, 5, 6]
# Transpiled circuit for local StatevectorSampler simulation.
# Executing simulation using local StatevectorSampler...

# %%
refdf = pd.read_csv("../../../classical/energies.csv",index_col=0).reset_index(drop=True)

# %%
refdf.loc[(refdf['Name'] == 'ammonia')&(refdf['Basis Set'] == 'STO-3G')]
